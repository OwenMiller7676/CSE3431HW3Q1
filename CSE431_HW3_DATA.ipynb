# %%
import matplotlib.pyplot as plt

# %%
#https://www.geeksforgeeks.org/graph-plotting-in-python-set-1/
insertion_raw_data = [0.0002535999999996319, 0.010275300000003096, 0.03445960000000148, 0.07881140000000086, 0.1471791999999974, 0.20386549999999581, 0.32916930000001043, 0.4185236000000039, 0.5697433000000114, 0.7698962999999841, 0.9355179999999974, 1.0878451000000275, 1.3489714000000106, 1.4798279999999924, 1.7803699999999925, 1.9884365999999005, 2.2793481999999976, 2.6654121999998814, 2.946803799999966, 3.0894521000000594, 3.3563256999998856, 4.0950631999999985, 4.485120899999998, 4.92778040000001, 5.492857899999954, 5.653793700000165, 6.474274300000161, 6.936759099999861, 7.368018099999873, 7.983228200000042, 8.526865600000235, 9.248177000000183, 9.79331090000042, 9.979938399999298, 10.665794699999793, 11.961468000000224, 12.27020079999977, 13.041033099999765, 13.73842519999991, 14.485634800000128]
merge_raw_data = [0.00025850000000160467, 0.015588700000001454, 0.035600899999996494, 0.054470599999999036, 0.07743929999999755, 0.10557329999999832, 0.1214426999999958, 0.14704979999999512, 0.17892039999999376, 0.18968309999999544, 0.21777909999999245, 0.24499619999997968, 0.2682167999999656, 0.29821760000002406, 0.31656350000001154, 0.3441539000000109, 0.36977909999994196, 0.39400859999994253, 0.4200252999999847, 0.45062399999992664, 0.4791018999999608, 0.5079940000000178, 0.5213678999998592, 0.5667813999999254, 0.5916952000000606, 0.6217784999999196, 0.6582428000000817, 0.6919557000002925, 0.703334799999979, 0.7280903999998998, 0.7910390999999066, 0.8362785000001338, 0.8115030999999959, 0.8361872999993807, 0.873045700000489, 0.8983642999997983, 0.9303050999998561, 0.9615836999997782, 0.998771200000391, 1.0152982999999267]
num_values = [0, 25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500, 525, 550, 575, 600, 625, 650, 675, 700, 725, 750, 775, 800, 825, 850, 875, 900, 925, 950, 975]



plt.figure(figsize=(5, 5))
plt.plot(num_values, insertion_raw_data, label='Insertion Sort',  color='blue') 
plt.plot(num_values, merge_raw_data, label='Merge Sort', color='red') 


plt.title('Algorithm Runtime') 
plt.xlabel('Number of Elements (N)') 
plt.ylabel('Time Taken (seconds)') 


plt.legend()


plt.show()

# %%
plt.figure(figsize=(15, 50))

plt.plot(num_values, insertion_raw_data, label='Insertion Sort',  color='blue') 
plt.plot(num_values, merge_raw_data, label='Merge Sort', color='red') 


plt.title('Algorithm Runtime') 
plt.xlabel('Number of Elements (N)') 
plt.ylabel('Time Taken (seconds)') 


plt.legend()


plt.show()
